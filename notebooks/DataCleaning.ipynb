# %% [markdown]
# **Limpieza de Datos**
#
# Para emepezar tenemos que cargar y limpiar la base de datos usando al libreria de Pandas.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/ensanut2022_muestras.csv", sep=";")
df.head()
# Out:
#          FOLIO_I         FOLIO_INT  t_hora  t_min  t_sumai  t_sumaf  \
# 0  2022_01001004  2022_01001004_01      13     35      813      815
# 1  2022_01001008  2022_01001008_01      20     44     1244     1244
# 2  2022_01001008  2022_01001008_03      20     43     1243     1243
# 3  2022_01001009  2022_01001009_02       9     26      561      566
# 4  2022_01001011  2022_01001011_01      20     49     1249     1249
#
#   hora_ini_1 fecha_ini_1 hora_fin_1 fecha_fin_1  ...  valor_VIT_D  \
# 0   13:33:14  10/11/2022   13:35:20  10/11/2022  ...
# 1   20:34:12  20/11/2022   20:34:55  20/11/2022  ...
# 2   20:41:51  20/11/2022   20:42:23  20/11/2022  ...
# 3   09:21:48  10/11/2022   09:26:03  10/11/2022  ...
# 4   20:45:31  20/11/2022   20:46:06  20/11/2022  ...
#
#    fecdeterm_VIT_D           ponde_v cuenta_mic ponde_m12a49 ponde_m0a11  \
# 0                                             0
# 1                                             0
# ...

# %% [markdown]
# Empezamos por imprimir todas las columnas para luego escoger con cuales nos queremos quedar

# %%
for col in df.columns:
    print(col)
# Out:
# FOLIO_I
# FOLIO_INT
# t_hora
# t_min
# t_sumai
# t_sumaf
# hora_ini_1
# fecha_ini_1
# hora_fin_1
# fecha_fin_1
# tiempo1
# resultado_1
# hora_ini_2
# fecha_ini_2
# hora_fin_2
# fecha_fin_2
# tiempo2
# resultado_2
# hora_ini_3
# fecha_ini_3
# hora_fin_3
# fecha_fin_3
# tiempo3
# resultado_3
# hora_ini_4
# fecha_ini_4
# hora_fin_4
# fecha_fin_4
# tiempo4
# resultado_4
# hora_ini
# fecha_ini
# localizado
# entidad
# desc_ent
# municipio
# desc_mun
# h0302
# h0303
# fech_nac
# sc
# sv
# sh
# sm
# int_hemoglobina
# nota1
# nota11
# nota00
# sc01
# sc02
# sc03
# sc04
# nota01
# san01
# san02
# san03
# san04
# san05
# san06
# nota02
# hb01
# hb02
# hb03
# hb04
# hb05
# hb06a
# hb06b
# hb07a
# hb07b
# hb08
# hb09
# hb10
# hb11
# nota03
# mc01
# mc02
# mc03
# comentario
# tiempo
# hora_fin
# fecha_fin
# completa
# otroent
# MATRIZ_SUERO
# valor_AC_URICO
# fecdeterm_AC_URICO
# valor_ALBU
# fecdeterm_ALBU
# valor_COL_HDL
# fecdeterm_COL_HDL
# valor_COL_LDL
# fecdeterm_COL_LDL
# valor_COLEST
# ...

# %%
wanted_columns = ["FOLIO_I", "entidad", "desc_ent", "municipio", 
                  "desc_mun", "estrato", "h0302", "h0303", 
                  "valor_COL_LDL", "valor_GLU_SUERO",  "valor_TRIG"]

numeric_cols = ["valor_COL_LDL", "valor_GLU_SUERO", "valor_TRIG",]
data = df[wanted_columns]

# %% [markdown]
# Renombramos unas columnas, quitamos filas con valores vacios y convertimos a valores tipo "float"

# %%
data[numeric_cols] = data[numeric_cols].replace({' ': pd.NA, ' ': pd.NA, ',': '.'})
data = data.rename(columns={'h0302': 'sexo', 'h0303': 'edad'})
data = data.reset_index().drop(columns=['index'])
# Out:
# C:\Users\juamp\AppData\Local\Temp\ipykernel_31124\2751596537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[numeric_cols] = data[numeric_cols].replace({' ': pd.NA, ' ': pd.NA, ',': '.'})

# %%
data = data.dropna()

for col in numeric_cols:
    data[col] = data[col].str.replace(',', '.')

data[numeric_cols] = data[numeric_cols].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2091 entries, 3 to 13897
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FOLIO_I          2091 non-null   object
#  1   entidad          2091 non-null   int64
#  2   desc_ent         2091 non-null   object
#  3   municipio        2091 non-null   int64
#  4   desc_mun         2091 non-null   object
#  5   estrato          2091 non-null   int64
#  6   sexo             2091 non-null   int64
#  7   edad             2091 non-null   int64
#  8   valor_COL_LDL    2091 non-null   float64
#  9   valor_GLU_SUERO  2091 non-null   float64
#  10  valor_TRIG       2091 non-null   float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 196.0+ KB

# %% [markdown]
# Finalmente guardamos los datos limpios para poder trabajar con ellos de manera mas facil

# %%
data.to_csv('../data/clean_data2.csv')
